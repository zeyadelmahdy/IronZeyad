# %% [markdown]
# # This is a header of the notebook

# %% [markdown]
# ### This Notebook will give an intro to my friend Zeyad, we will go through his holiday preferences and and show you what places he likes to visit

# %%
a = input("Please enter your name here: ")
# Out:
# Please enter your name here: Zeyad

# %% [markdown]
# ![286816b4-a267-4542-bd3b-2dd59e183bd8.jpg](attachment:286816b4-a267-4542-bd3b-2dd59e183bd8.jpg)

# %%
a = input("Do you prefer sun or snow? ")
b = input("Are you an active person or are you a couch potato? ")
# Out:
# Do you prefer sun or snow? Sun
# Are you an active person or are you a couch potato? active as hell

# %%
c = input("Lisbon or Berlin? ")
# Out:
# Lisbon or Berlin? Lisbon man

# %% [markdown]
# ![LIS.jpg.1533900488019.image.750.563.low.jpg](attachment:LIS.jpg.1533900488019.image.750.563.low.jpg)

# %% [markdown]
# - Eat Seafood and Pastel de Natas
# - Walk all day long
# - Go surfing

# %% [markdown]
# - <span style="color:red">Eat Seafood and Pastel de Natas</span>.
# - **Walk all day long**
# - _Go surfing_

# %% [markdown]
# ["This is a link to a Youtube Video"](https://www.youtube.com/watch?v=IC7hvQfQkWE&ab_channel=Eater)
